# %% [markdown]
# Os passos básicos para criação de um modelo de Machine Learning e sua implementação são:
# 1. Entendimento do negócio
# 2. Entendimento dos dados
# 3. Preparação dos dados
# 4. Modelagem
# 5. Avaliação
# 6. Implantação

# %% [markdown]
# Conhecido como CRISP-DM (Cros
